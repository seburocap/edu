# %%
import numpy as np
import pandas as pd
import requests
import time
from datetime import datetime, timedelta
from statsmodels.tsa.stattools import adfuller
from collections import deque
import warnings
warnings.filterwarnings('ignore')

class StationarityMonitor:
    def __init__(self, symbol='BTCUSDT', interval='1m', window_size=10):
        self.symbol = symbol
        self.interval = interval
        self.window_size = window_size  # размер окна в минутах
        
        # Очереди для хранения данных
        self.prices = deque(maxlen=window_size)
        self.timestamps = deque(maxlen=window_size)
        
        # История ADF статистик для отслеживания динамики
        self.adf_history = {
            'sma_deviation': deque(maxlen=50),
            'bollinger': deque(maxlen=50),
            'return_deviation': deque(maxlen=50)
        }
        
        # Параметры для стратегий
        self.sma_period = 50
        self.bb_period = 20
        self.bb_std = 2
        
        print(f"Инициализирован мониторинг стационарности для {symbol}")
        print(f"Размер окна: {window_size} минут")
        
    def get_klines_data(self, limit=100):
        """Получение данных свечей с Binance API"""
        url = "https://api.binance.com/api/v3/klines"
        params = {
            'symbol': self.symbol,
            'interval': self.interval,
            'limit': limit
        }
        
        try:
            response = requests.get(url, params=params)
            response.raise_for_status()
            data = response.json()
            
            df = pd.DataFrame(data, columns=[
                'timestamp', 'open', 'high', 'low', 'close', 'volume',
                'close_time', 'quote_asset_volume', 'number_of_trades',
                'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore'
            ])
            
            # Конвертация типов
            numeric_columns = ['open', 'high', 'low', 'close', 'volume']
            for col in numeric_columns:
                df[col] = pd.to_numeric(df[col])
            
            df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
            return df
            
        except Exception as e:
            print(f"Ошибка получения данных: {e}")
            return None
    
    def calculate_sma(self, prices, period):
        """Расчет Simple Moving Average"""
        if len(prices) < period:
            return None
        return sum(list(prices)[-period:]) / period
    
    def calculate_bollinger_bands(self, prices, period, std_dev):
        """Расчет Bollinger Bands"""
        if len(prices) < period:
            return None, None, None
        
        recent_prices = list(prices)[-period:]
        sma = sum(recent_prices) / period
        std = np.std(recent_prices)
        
        upper_band = sma + (std_dev * std)
        lower_band = sma - (std_dev * std)
        
        return sma, upper_band, lower_band
    
    def calculate_returns(self, prices):
        """Расчет доходности"""
        if len(prices) < 2:
            return []
        
        prices_list = list(prices)
        returns = []
        for i in range(1, len(prices_list)):
            ret = (prices_list[i] - prices_list[i-1]) / prices_list[i-1]
            returns.append(ret)
        
        return returns
    
    def perform_adf_test(self, series, test_name):
        """Выполнение ADF теста"""
        if len(series) < 10:  # Минимум данных для теста
            return None, None, None
        
        try:
            result = adfuller(series)
            adf_stat = result[0]
            p_value = result[1]
            critical_values = result[4]
            
            # Определение стационарности на основе критических значений
            is_stationary = adf_stat < critical_values['5%']
            
            return adf_stat, p_value, is_stationary
            
        except Exception as e:
            print(f"Ошибка ADF теста для {test_name}: {e}")
            return None, None, None
    
    def check_adf_trend(self, strategy_name, current_adf):
        """Проверка динамики ADF статистики"""
        history = self.adf_history[strategy_name]
        
        if current_adf is not None:
            history.append(current_adf)
        
        if len(history) < 3:
            return "Недостаточно данных"
        
        # Проверяем тренд последних 3 значений
        recent_values = list(history)[-3:]
        
        # ADF статистика снижается (становится менее отрицательной) = хуже для стационарности
        if recent_values[-1] > recent_values[-2] > recent_values[-3]:
            return "⚠️ ADF СНИЖАЕТСЯ"
        elif recent_values[-1] < recent_values[-2] < recent_values[-3]:
            return "✅ ADF улучшается"
        else:
            return "→ ADF стабильна"
    
    def analyze_strategies(self, df):
        """Анализ всех стратегий"""
        if len(df) < max(self.sma_period, self.bb_period):
            print("Недостаточно данных для анализа")
            return
        
        current_price = df['close'].iloc[-1]
        prices = df['close'].values
        
        print(f"\n{'='*80}")
        print(f"Время: {datetime.now().strftime('%H:%M:%S')} | Цена BTC: ${current_price:.2f}")
        print(f"{'='*80}")
        
        # Стратегия 1: Отклонение от SMA
        if len(prices) >= self.sma_period:
            sma_value = self.calculate_sma(prices, self.sma_period)
            if sma_value:
                # Используем только последние window_size точек для ADF
                recent_prices = prices[-self.window_size:] if len(prices) >= self.window_size else prices
                recent_sma = [self.calculate_sma(prices[:i+1], min(self.sma_period, i+1)) 
                             for i in range(len(recent_prices))]
                recent_sma = [x for x in recent_sma if x is not None]
                
                if len(recent_sma) > 0:
                    sma_deviations = recent_prices[-len(recent_sma):] - np.array(recent_sma)
                    adf_stat, p_value, is_stationary = self.perform_adf_test(sma_deviations, "SMA отклонение")
                    trend = self.check_adf_trend('sma_deviation', adf_stat)
                    
                    print(f"\n📊 СТРАТЕГИЯ 1: Отклонение от SMA({self.sma_period})")
                    print(f"   Текущая цена: ${current_price:.2f}")
                    print(f"   SMA: ${sma_value:.2f}")
                    print(f"   Отклонение: ${current_price - sma_value:.2f} ({((current_price/sma_value-1)*100):.2f}%)")
                    if adf_stat is not None:
                        print(f"   ADF статистика: {adf_stat:.4f}")
                        print(f"   P-value: {p_value:.4f}")
                        print(f"   Стационарность: {'✅ ДА' if is_stationary else '❌ НЕТ'}")
                        print(f"   Тренд ADF: {trend}")
        
        # Стратегия 2: Bollinger Bands
        if len(prices) >= self.bb_period:
            bb_sma, upper_band, lower_band = self.calculate_bollinger_bands(
                prices, self.bb_period, self.bb_std
            )
            
            if bb_sma and upper_band and lower_band:
                # BB позиция для последних window_size точек
                recent_prices = prices[-self.window_size:] if len(prices) >= self.window_size else prices
                bb_positions = []
                
                for i, price in enumerate(recent_prices):
                    start_idx = max(0, len(prices) - len(recent_prices) + i - self.bb_period + 1)
                    end_idx = len(prices) - len(recent_prices) + i + 1
                    
                    if end_idx - start_idx >= self.bb_period:
                        period_prices = prices[start_idx:end_idx]
                        sma, upper, lower = self.calculate_bollinger_bands(
                            period_prices, self.bb_period, self.bb_std
                        )
                        if sma and upper and lower:
                            if price > upper:
                                bb_positions.append(1)  # Выше верхней полосы
                            elif price < lower:
                                bb_positions.append(-1)  # Ниже нижней полосы
                            else:
                                bb_positions.append(0)  # Внутри полос
                
                if len(bb_positions) > 5:
                    adf_stat, p_value, is_stationary = self.perform_adf_test(bb_positions, "Bollinger Bands")
                    trend = self.check_adf_trend('bollinger', adf_stat)
                    
                    print(f"\n📊 СТРАТЕГИЯ 2: Bollinger Bands({self.bb_period}, {self.bb_std})")
                    print(f"   Верхняя полоса: ${upper_band:.2f}")
                    print(f"   Средняя линия: ${bb_sma:.2f}")
                    print(f"   Нижняя полоса: ${lower_band:.2f}")
                    
                    current_bb_pos = ""
                    if current_price > upper_band:
                        current_bb_pos = "🔴 Выше верхней полосы"
                    elif current_price < lower_band:
                        current_bb_pos = "🟢 Ниже нижней полосы"
                    else:
                        current_bb_pos = "🟡 Внутри полос"
                    
                    print(f"   Позиция: {current_bb_pos}")
                    if adf_stat is not None:
                        print(f"   ADF статистика: {adf_stat:.4f}")
                        print(f"   P-value: {p_value:.4f}")
                        print(f"   Стационарность: {'✅ ДА' if is_stationary else '❌ НЕТ'}")
                        print(f"   Тренд ADF: {trend}")
        
        # Стратегия 3: Отклонение доходности от средней
        if len(prices) >= 10:
            returns = self.calculate_returns(prices[-self.window_size:] if len(prices) >= self.window_size else prices)
            
            if len(returns) > 5:
                mean_return = np.mean(returns)
                return_deviations = np.array(returns) - mean_return
                
                adf_stat, p_value, is_stationary = self.perform_adf_test(return_deviations, "Отклонение доходности")
                trend = self.check_adf_trend('return_deviation', adf_stat)
                
                print(f"\n📊 СТРАТЕГИЯ 3: Отклонение доходности от средней")
                print(f"   Средняя доходность: {mean_return*100:.4f}%")
                print(f"   Последняя доходность: {returns[-1]*100:.4f}%")
                print(f"   Отклонение: {(returns[-1] - mean_return)*100:.4f}%")
                print(f"   Волатильность: {np.std(returns)*100:.4f}%")
                if adf_stat is not None:
                    print(f"   ADF статистика: {adf_stat:.4f}")
                    print(f"   P-value: {p_value:.4f}")
                    print(f"   Стационарность: {'✅ ДА' if is_stationary else '❌ НЕТ'}")
                    print(f"   Тренд ADF: {trend}")
    
    def run_monitoring(self, update_interval=60):
        """Запуск мониторинга в реальном времени"""
        print(f"🚀 Запуск мониторинга стационарности для {self.symbol}")
        print(f"⏱️ Интервал обновления: {update_interval} секунд")
        print(f"📊 Размер окна для ADF: {self.window_size} минут")
        
        while True:
            try:
                # Получаем данные
                df = self.get_klines_data(limit=200)  # Берем больше данных для SMA
                
                if df is not None and len(df) > 0:
                    self.analyze_strategies(df)
                else:
                    print("❌ Не удалось получить данные")
                
                # Ждем до следующего обновления
                print(f"\n⏳ Следующее обновление через {update_interval} секунд...")
                time.sleep(update_interval)
                
            except KeyboardInterrupt:
                print("\n🛑 Мониторинг остановлен пользователем")
                break
            except Exception as e:
                print(f"❌ Ошибка в мониторинге: {e}")
                time.sleep(update_interval)

# Пример использования
if __name__ == "__main__":
    # Создаем монитор
    monitor = StationarityMonitor(
        symbol='BTCUSDT',
        interval='1m',
        window_size=15  # 15-минутное окно для ADF теста
    )
    
    # Запускаем мониторинг (обновление каждые 60 секунд)
    monitor.run_monitoring(update_interval=60)
# Out:
# Инициализирован мониторинг стационарности для BTCUSDT
# Размер окна: 15 минут
# 🚀 Запуск мониторинга стационарности для BTCUSDT
# ⏱️ Интервал обновления: 60 секунд
# 📊 Размер окна для ADF: 15 минут
#
# ================================================================================
# Время: 14:24:06 | Цена BTC: $107293.82
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107293.82
#    SMA: $107223.39
#    Отклонение: $70.43 (0.07%)
#    ADF статистика: -6.4509
#    P-value: 0.0000
#    Стационарность: ✅ ДА
#    Тренд ADF: Недостаточно данных
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107421.91
#    Средняя линия: $107316.42
#    Нижняя полоса: $107210.93
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: -0.0045%
#    Последняя доходность: -0.0070%
#    Отклонение: -0.0025%
#    Волатильность: 0.0553%
#    ADF статистика: -7.2222
#    P-value: 0.0000
#    Стационарность: ✅ ДА
#    Тренд ADF: Недостаточно данных
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:25:06 | Цена BTC: $107317.40
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107317.40
#    SMA: $107226.82
#    Отклонение: $90.58 (0.08%)
#    ADF статистика: -16.3750
#    P-value: 0.0000
#    Стационарность: ✅ ДА
#    Тренд ADF: Недостаточно данных
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107418.83
#    Средняя линия: $107315.27
#    Нижняя полоса: $107211.71
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: -0.0074%
#    Последняя доходность: 0.0078%
#    Отклонение: 0.0152%
#    Волатильность: 0.0525%
#    ADF статистика: -2.5207
#    P-value: 0.1105
#    Стационарность: ❌ НЕТ
#    Тренд ADF: Недостаточно данных
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:26:07 | Цена BTC: $107292.15
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107292.15
#    SMA: $107229.66
#    Отклонение: $62.49 (0.06%)
#    ADF статистика: -3.5070
#    P-value: 0.0078
#    Стационарность: ✅ ДА
#    Тренд ADF: → ADF стабильна
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107409.03
#    Средняя линия: $107308.64
#    Нижняя полоса: $107208.25
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: -0.0055%
#    Последняя доходность: 0.0160%
#    Отклонение: 0.0215%
#    Волатильность: 0.0519%
#    ADF статистика: -6.4463
#    P-value: 0.0000
#    Стационарность: ✅ ДА
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:27:07 | Цена BTC: $107317.39
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107317.39
#    SMA: $107232.96
#    Отклонение: $84.43 (0.08%)
#    ADF статистика: -3.3579
#    P-value: 0.0125
#    Стационарность: ✅ ДА
#    Тренд ADF: ⚠️ ADF СНИЖАЕТСЯ
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107406.58
#    Средняя линия: $107307.05
#    Нижняя полоса: $107207.52
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0062%
#    Последняя доходность: 0.0297%
#    Отклонение: 0.0235%
#    Волатильность: 0.0363%
#    ADF статистика: -1.9175
#    P-value: 0.3239
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:28:07 | Цена BTC: $107344.79
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107344.79
#    SMA: $107236.95
#    Отклонение: $107.84 (0.10%)
#    ADF статистика: -2.3407
#    P-value: 0.1592
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ⚠️ ADF СНИЖАЕТСЯ
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107408.07
#    Средняя линия: $107307.98
#    Нижняя полоса: $107207.89
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0083%
#    Последняя доходность: -0.0000%
#    Отклонение: -0.0083%
#    Волатильность: 0.0380%
#    ADF статистика: -6.3380
#    P-value: 0.0000
#    Стационарность: ✅ ДА
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:29:08 | Цена BTC: $107362.51
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107362.51
#    SMA: $107243.43
#    Отклонение: $119.08 (0.11%)
#    ADF статистика: -1.7130
#    P-value: 0.4245
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ⚠️ ADF СНИЖАЕТСЯ
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107412.93
#    Средняя линия: $107309.65
#    Нижняя полоса: $107206.37
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0032%
#    Последняя доходность: -0.0064%
#    Отклонение: -0.0096%
#    Волатильность: 0.0314%
#    ADF статистика: -3.5550
#    P-value: 0.0067
#    Стационарность: ✅ ДА
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:30:09 | Цена BTC: $107349.59
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107349.59
#    SMA: $107248.77
#    Отклонение: $100.82 (0.09%)
#    ADF статистика: -1.9930
#    P-value: 0.2897
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107408.53
#    Средняя линия: $107308.07
#    Нижняя полоса: $107207.60
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0057%
#    Последняя доходность: 0.0059%
#    Отклонение: 0.0002%
#    Волатильность: 0.0291%
#    ADF статистика: -4.5859
#    P-value: 0.0001
#    Стационарность: ✅ ДА
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:31:09 | Цена BTC: $107366.63
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107366.63
#    SMA: $107254.65
#    Отклонение: $111.98 (0.10%)
#    ADF статистика: -2.2067
#    P-value: 0.2038
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ✅ ADF улучшается
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107396.35
#    Средняя линия: $107305.82
#    Нижняя полоса: $107215.29
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0024%
#    Последняя доходность: 0.0000%
#    Отклонение: -0.0024%
#    Волатильность: 0.0252%
#    ADF статистика: -4.0414
#    P-value: 0.0012
#    Стационарность: ✅ ДА
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:32:10 | Цена BTC: $107288.93
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107288.93
#    SMA: $107255.34
#    Отклонение: $33.59 (0.03%)
#    ADF статистика: -2.5260
#    P-value: 0.1093
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ✅ ADF улучшается
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107377.29
#    Средняя линия: $107297.77
#    Нижняя полоса: $107218.26
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: -0.0015%
#    Последняя доходность: -0.0030%
#    Отклонение: -0.0015%
#    Волатильность: 0.0310%
#    ADF статистика: -2.8855
#    P-value: 0.0471
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ⚠️ ADF СНИЖАЕТСЯ
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:33:10 | Цена BTC: $107280.40
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107280.40
#    SMA: $107256.60
#    Отклонение: $23.80 (0.02%)
#    ADF статистика: -1.5625
#    P-value: 0.5024
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107373.18
#    Средняя линия: $107299.89
#    Нижняя полоса: $107226.59
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0013%
#    Последняя доходность: 0.0050%
#    Отклонение: 0.0037%
#    Волатильность: 0.0286%
#    ADF статистика: -0.9783
#    P-value: 0.7611
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ⚠️ ADF СНИЖАЕТСЯ
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:34:10 | Цена BTC: $107285.47
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107285.47
#    SMA: $107259.02
#    Отклонение: $26.45 (0.02%)
#    ADF статистика: -1.8291
#    P-value: 0.3661
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107367.20
#    Средняя линия: $107303.38
#    Нижняя полоса: $107239.56
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0011%
#    Последняя доходность: 0.0000%
#    Отклонение: -0.0011%
#    Волатильность: 0.0286%
#    ADF статистика: -3.3839
#    P-value: 0.0115
#    Стационарность: ✅ ДА
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:35:11 | Цена BTC: $107254.61
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107254.61
#    SMA: $107261.54
#    Отклонение: $-6.93 (-0.01%)
#    ADF статистика: -1.0797
#    P-value: 0.7231
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107368.47
#    Средняя линия: $107298.82
#    Нижняя полоса: $107229.18
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: -0.0018%
#    Последняя доходность: 0.0000%
#    Отклонение: 0.0018%
#    Волатильность: 0.0294%
#    ADF статистика: -3.6024
#    P-value: 0.0057
#    Стационарность: ✅ ДА
#    Тренд ADF: ✅ ADF улучшается
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:36:11 | Цена BTC: $107305.83
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107305.83
#    SMA: $107267.37
#    Отклонение: $38.46 (0.04%)
#    ADF статистика: -1.1690
#    P-value: 0.6868
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107367.92
#    Средняя линия: $107303.46
#    Нижняя полоса: $107239.01
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0002%
#    Последняя доходность: -0.0000%
#    Отклонение: -0.0003%
#    Волатильность: 0.0317%
#    ADF статистика: -15.5688
#    P-value: 0.0000
#    Стационарность: ✅ ДА
#    Тренд ADF: ✅ ADF улучшается
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:37:11 | Цена BTC: $107325.00
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107325.00
#    SMA: $107273.35
#    Отклонение: $51.65 (0.05%)
#    ADF статистика: -0.3566
#    P-value: 0.9171
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107369.52
#    Средняя линия: $107304.41
#    Нижняя полоса: $107239.30
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0016%
#    Последняя доходность: -0.0046%
#    Отклонение: -0.0062%
#    Волатильность: 0.0322%
#    ADF статистика: 1.3678
#    P-value: 0.9970
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:38:12 | Цена BTC: $107289.84
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107289.84
#    SMA: $107276.56
#    Отклонение: $13.28 (0.01%)
#    ADF статистика: 0.7109
#    P-value: 0.9901
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ⚠️ ADF СНИЖАЕТСЯ
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107366.62
#    Средняя линия: $107302.06
#    Нижняя полоса: $107237.51
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: -0.0013%
#    Последняя доходность: -0.0097%
#    Отклонение: -0.0084%
#    Волатильность: 0.0331%
#    ADF статистика: -3.7362
#    P-value: 0.0036
#    Стационарность: ✅ ДА
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:39:12 | Цена BTC: $107292.15
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107292.15
#    SMA: $107280.03
#    Отклонение: $12.12 (0.01%)
#    ADF статистика: 0.6918
#    P-value: 0.9897
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107365.59
#    Средняя линия: $107303.87
#    Нижняя полоса: $107242.14
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0011%
#    Последняя доходность: -0.0019%
#    Отклонение: -0.0031%
#    Волатильность: 0.0320%
#    ADF статистика: -1.6021
#    P-value: 0.4825
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:40:13 | Цена BTC: $107261.81
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107261.81
#    SMA: $107282.20
#    Отклонение: $-20.39 (-0.02%)
#    ADF статистика: 1.0063
#    P-value: 0.9943
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107367.60
#    Средняя линия: $107301.67
#    Нижняя полоса: $107235.73
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: -0.0016%
#    Последняя доходность: 0.0063%
#    Отклонение: 0.0079%
#    Волатильность: 0.0333%
#    ADF статистика: -1.4567
#    P-value: 0.5548
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ⚠️ ADF СНИЖАЕТСЯ
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:41:13 | Цена BTC: $107284.88
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107284.88
#    SMA: $107284.76
#    Отклонение: $0.12 (0.00%)
#    ADF статистика: -0.1984
#    P-value: 0.9387
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107366.66
#    Средняя линия: $107302.97
#    Нижняя полоса: $107239.28
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: -0.0040%
#    Последняя доходность: 0.0000%
#    Отклонение: 0.0040%
#    Волатильность: 0.0305%
#    ADF статистика: -2.4139
#    P-value: 0.1378
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:42:13 | Цена BTC: $107298.59
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107298.59
#    SMA: $107288.36
#    Отклонение: $10.23 (0.01%)
#    ADF статистика: -1.6219
#    P-value: 0.4717
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ✅ ADF улучшается
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107366.50
#    Средняя линия: $107302.97
#    Нижняя полоса: $107239.43
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: -0.0047%
#    Последняя доходность: 0.0095%
#    Отклонение: 0.0142%
#    Волатильность: 0.0299%
#    ADF статистика: -1.7158
#    P-value: 0.4230
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:43:14 | Цена BTC: $107322.36
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107322.36
#    SMA: $107291.05
#    Отклонение: $31.31 (0.03%)
#    ADF статистика: -1.5720
#    P-value: 0.4977
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107368.19
#    Средняя линия: $107304.14
#    Нижняя полоса: $107240.08
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: -0.0014%
#    Последняя доходность: 0.0199%
#    Отклонение: 0.0213%
#    Волатильность: 0.0301%
#    ADF статистика: -27.4061
#    P-value: 0.0000
#    Стационарность: ✅ ДА
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:44:14 | Цена BTC: $107289.63
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107289.63
#    SMA: $107293.43
#    Отклонение: $-3.80 (-0.00%)
#    ADF статистика: -1.1481
#    P-value: 0.6955
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ⚠️ ADF СНИЖАЕТСЯ
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107365.48
#    Средняя линия: $107301.53
#    Нижняя полоса: $107237.59
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: -0.0051%
#    Последняя доходность: 0.0000%
#    Отклонение: 0.0051%
#    Волатильность: 0.0288%
#    ADF статистика: -3.6760
#    P-value: 0.0045
#    Стационарность: ✅ ДА
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:45:14 | Цена BTC: $107292.00
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107292.00
#    SMA: $107296.02
#    Отклонение: $-4.02 (-0.00%)
#    ADF статистика: -10.1581
#    P-value: 0.0000
#    Стационарность: ✅ ДА
#    Тренд ADF: → ADF стабильна
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107365.34
#    Средняя линия: $107302.38
#    Нижняя полоса: $107239.43
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: -0.0000%
#    Последняя доходность: 0.0022%
#    Отклонение: 0.0022%
#    Волатильность: 0.0226%
#    ADF статистика: -3.4344
#    P-value: 0.0098
#    Стационарность: ✅ ДА
#    Тренд ADF: ⚠️ ADF СНИЖАЕТСЯ
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:46:15 | Цена BTC: $107277.93
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107277.93
#    SMA: $107298.04
#    Отклонение: $-20.11 (-0.02%)
#    ADF статистика: -10.7718
#    P-value: 0.0000
#    Стационарность: ✅ ДА
#    Тренд ADF: ✅ ADF улучшается
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107365.48
#    Средняя линия: $107301.30
#    Нижняя полоса: $107237.11
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0002%
#    Последняя доходность: 0.0000%
#    Отклонение: -0.0002%
#    Волатильность: 0.0224%
#    ADF статистика: -8.7531
#    P-value: 0.0000
#    Стационарность: ✅ ДА
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:47:15 | Цена BTC: $107238.90
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107238.90
#    SMA: $107299.82
#    Отклонение: $-60.92 (-0.06%)
#    ADF статистика: -1.2617
#    P-value: 0.6465
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107363.75
#    Средняя линия: $107294.51
#    Нижняя полоса: $107225.27
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: -0.0031%
#    Последняя доходность: -0.0085%
#    Отклонение: -0.0054%
#    Волатильность: 0.0233%
#    ADF статистика: -2.5514
#    P-value: 0.1035
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:48:16 | Цена BTC: $107300.00
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107300.00
#    SMA: $107304.79
#    Отклонение: $-4.79 (-0.00%)
#    ADF статистика: -2.7147
#    P-value: 0.0715
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107349.47
#    Средняя линия: $107294.09
#    Нижняя полоса: $107238.72
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0030%
#    Последняя доходность: 0.0000%
#    Отклонение: -0.0030%
#    Волатильность: 0.0255%
#    ADF статистика: -4.8645
#    P-value: 0.0000
#    Стационарность: ✅ ДА
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:49:16 | Цена BTC: $107336.00
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107336.00
#    SMA: $107308.03
#    Отклонение: $27.97 (0.03%)
#    ADF статистика: -3.1534
#    P-value: 0.0228
#    Стационарность: ✅ ДА
#    Тренд ADF: ✅ ADF улучшается
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107350.33
#    Средняя линия: $107294.83
#    Нижняя полоса: $107239.33
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0020%
#    Последняя доходность: 0.0131%
#    Отклонение: 0.0110%
#    Волатильность: 0.0231%
#    ADF статистика: -3.9298
#    P-value: 0.0018
#    Стационарность: ✅ ДА
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:50:16 | Цена BTC: $107338.99
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107338.99
#    SMA: $107310.69
#    Отклонение: $28.30 (0.03%)
#    ADF статистика: -5.7032
#    P-value: 0.0000
#    Стационарность: ✅ ДА
#    Тренд ADF: ✅ ADF улучшается
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107342.61
#    Средняя линия: $107293.41
#    Нижняя полоса: $107244.22
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0006%
#    Последняя доходность: 0.0034%
#    Отклонение: 0.0028%
#    Волатильность: 0.0224%
#    ADF статистика: -3.7619
#    P-value: 0.0033
#    Стационарность: ✅ ДА
#    Тренд ADF: ⚠️ ADF СНИЖАЕТСЯ
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:51:17 | Цена BTC: $107317.39
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107317.39
#    SMA: $107310.10
#    Отклонение: $7.29 (0.01%)
#    ADF статистика: -3.1669
#    P-value: 0.0220
#    Стационарность: ✅ ДА
#    Тренд ADF: → ADF стабильна
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107338.32
#    Средняя линия: $107292.33
#    Нижняя полоса: $107246.34
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0011%
#    Последняя доходность: 0.0235%
#    Отклонение: 0.0224%
#    Волатильность: 0.0245%
#    ADF статистика: -4.1893
#    P-value: 0.0007
#    Стационарность: ✅ ДА
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:52:17 | Цена BTC: $107307.99
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107307.99
#    SMA: $107309.96
#    Отклонение: $-1.97 (-0.00%)
#    ADF статистика: -4.2843
#    P-value: 0.0005
#    Стационарность: ✅ ДА
#    Тренд ADF: → ADF стабильна
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107339.24
#    Средняя линия: $107293.81
#    Нижняя полоса: $107248.39
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0009%
#    Последняя доходность: -0.0056%
#    Отклонение: -0.0065%
#    Волатильность: 0.0243%
#    ADF статистика: -1.7229
#    P-value: 0.4194
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:53:17 | Цена BTC: $107324.78
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107324.78
#    SMA: $107310.15
#    Отклонение: $14.63 (0.01%)
#    ADF статистика: -2.7361
#    P-value: 0.0680
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107344.46
#    Средняя линия: $107296.38
#    Нижняя полоса: $107248.29
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0046%
#    Последняя доходность: 0.0045%
#    Отклонение: -0.0002%
#    Волатильность: 0.0218%
#    ADF статистика: -4.1383
#    P-value: 0.0008
#    Стационарность: ✅ ДА
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:54:18 | Цена BTC: $107310.60
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107310.60
#    SMA: $107308.10
#    Отклонение: $2.50 (0.00%)
#    ADF статистика: -2.5452
#    P-value: 0.1049
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ⚠️ ADF СНИЖАЕТСЯ
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107341.66
#    Средняя линия: $107298.47
#    Нижняя полоса: $107255.28
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0017%
#    Последняя доходность: 0.0000%
#    Отклонение: -0.0017%
#    Волатильность: 0.0210%
#    ADF статистика: -37.0933
#    P-value: 0.0000
#    Стационарность: ✅ ДА
#    Тренд ADF: ✅ ADF улучшается
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:55:18 | Цена BTC: $107282.71
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107282.71
#    SMA: $107306.08
#    Отклонение: $-23.37 (-0.02%)
#    ADF статистика: -3.7260
#    P-value: 0.0038
#    Стационарность: ✅ ДА
#    Тренд ADF: → ADF стабильна
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107339.49
#    Средняя линия: $107295.92
#    Нижняя полоса: $107252.35
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: -0.0004%
#    Последняя доходность: -0.0000%
#    Отклонение: 0.0004%
#    Волатильность: 0.0222%
#    ADF статистика: -1.3018
#    P-value: 0.6283
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:56:18 | Цена BTC: $107290.42
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107290.42
#    SMA: $107304.40
#    Отклонение: $-13.98 (-0.01%)
#    ADF статистика: -1.3720
#    P-value: 0.5956
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107334.74
#    Средняя линия: $107294.33
#    Нижняя полоса: $107253.91
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: -0.0007%
#    Последняя доходность: 0.0000%
#    Отклонение: 0.0007%
#    Волатильность: 0.0220%
#    ADF статистика: -1.1702
#    P-value: 0.6863
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ⚠️ ADF СНИЖАЕТСЯ
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:57:19 | Цена BTC: $107302.01
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107302.01
#    SMA: $107303.82
#    Отклонение: $-1.81 (-0.00%)
#    ADF статистика: -1.3374
#    P-value: 0.6119
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ⚠️ ADF СНИЖАЕТСЯ
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107335.55
#    Средняя линия: $107295.00
#    Нижняя полоса: $107254.44
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0008%
#    Последняя доходность: 0.0000%
#    Отклонение: -0.0008%
#    Волатильность: 0.0220%
#    ADF статистика: -2.8821
#    P-value: 0.0475
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:58:19 | Цена BTC: $107214.21
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107214.21
#    SMA: $107299.13
#    Отклонение: $-84.92 (-0.08%)
#    ADF статистика: 1.4481
#    P-value: 0.9973
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ⚠️ ADF СНИЖАЕТСЯ
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107350.88
#    Средняя линия: $107286.26
#    Нижняя полоса: $107221.63
#    Позиция: 🟢 Ниже нижней полосы
#    ADF статистика: -0.2673
#    P-value: 0.9300
#    Стационарность: ❌ НЕТ
#    Тренд ADF: Недостаточно данных
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: -0.0050%
#    Последняя доходность: 0.0065%
#    Отклонение: 0.0116%
#    Волатильность: 0.0320%
#    ADF статистика: -2.8886
#    P-value: 0.0467
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ✅ ADF улучшается
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 14:59:20 | Цена BTC: $107199.43
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107199.43
#    SMA: $107295.63
#    Отклонение: $-96.20 (-0.09%)
#    ADF статистика: 1.4482
#    P-value: 0.9973
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ⚠️ ADF СНИЖАЕТСЯ
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107360.70
#    Средняя линия: $107282.42
#    Нижняя полоса: $107204.14
#    Позиция: 🟢 Ниже нижней полосы
#    ADF статистика: -0.3948
#    P-value: 0.9110
#    Стационарность: ❌ НЕТ
#    Тренд ADF: Недостаточно данных
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: -0.0052%
#    Последняя доходность: 0.0059%
#    Отклонение: 0.0111%
#    Волатильность: 0.0320%
#    ADF статистика: -3.0023
#    P-value: 0.0347
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ✅ ADF улучшается
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 15:00:20 | Цена BTC: $107192.99
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107192.99
#    SMA: $107292.12
#    Отклонение: $-99.13 (-0.09%)
#    ADF статистика: 1.0423
#    P-value: 0.9947
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107366.12
#    Средняя линия: $107277.50
#    Нижняя полоса: $107188.89
#    Позиция: 🟡 Внутри полос
#    ADF статистика: -3.1623
#    P-value: 0.0223
#    Стационарность: ✅ ДА
#    Тренд ADF: ✅ ADF улучшается
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: -0.0037%
#    Последняя доходность: 0.0000%
#    Отклонение: 0.0037%
#    Волатильность: 0.0313%
#    ADF статистика: -3.7574
#    P-value: 0.0034
#    Стационарность: ✅ ДА
#    Тренд ADF: ✅ ADF улучшается
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 15:01:20 | Цена BTC: $107137.04
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107137.04
#    SMA: $107285.52
#    Отклонение: $-148.48 (-0.14%)
#    ADF статистика: -0.4453
#    P-value: 0.9023
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ✅ ADF улучшается
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107382.06
#    Средняя линия: $107268.02
#    Нижняя полоса: $107153.98
#    Позиция: 🟢 Ниже нижней полосы
#    ADF статистика: -0.6172
#    P-value: 0.8670
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: -0.0109%
#    Последняя доходность: -0.0164%
#    Отклонение: -0.0056%
#    Волатильность: 0.0286%
#    ADF статистика: -2.5798
#    P-value: 0.0972
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 15:02:21 | Цена BTC: $107237.65
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107237.65
#    SMA: $107284.13
#    Отклонение: $-46.48 (-0.04%)
#    ADF статистика: -1.6098
#    P-value: 0.4787
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ✅ ADF улучшается
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107369.89
#    Средняя линия: $107268.26
#    Нижняя полоса: $107166.63
#    Позиция: 🟡 Внутри полос
#    ADF статистика: -1.5954
#    P-value: 0.4859
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: -0.0056%
#    Последняя доходность: 0.0302%
#    Отклонение: 0.0358%
#    Волатильность: 0.0328%
#    ADF статистика: -1.7026
#    P-value: 0.4298
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ⚠️ ADF СНИЖАЕТСЯ
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 15:03:21 | Цена BTC: $107240.00
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107240.00
#    SMA: $107284.02
#    Отклонение: $-44.02 (-0.04%)
#    ADF статистика: -2.0231
#    P-value: 0.2766
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ✅ ADF улучшается
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107368.13
#    Средняя линия: $107264.73
#    Нижняя полоса: $107161.34
#    Позиция: 🟡 Внутри полос
#    ADF статистика: -1.5954
#    P-value: 0.4859
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: -0.0063%
#    Последняя доходность: 0.0217%
#    Отклонение: 0.0280%
#    Волатильность: 0.0322%
#    ADF статистика: -3.0936
#    P-value: 0.0270
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 15:04:22 | Цена BTC: $107302.36
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107302.36
#    SMA: $107286.87
#    Отклонение: $15.49 (0.01%)
#    ADF статистика: -0.5557
#    P-value: 0.8807
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107372.92
#    Средняя линия: $107268.38
#    Нижняя полоса: $107163.85
#    Позиция: 🟡 Внутри полос
#    ADF статистика: -2.3452
#    P-value: 0.1578
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0007%
#    Последняя доходность: 0.0019%
#    Отклонение: 0.0012%
#    Волатильность: 0.0369%
#    ADF статистика: -296.4529
#    P-value: 0.0000
#    Стационарность: ✅ ДА
#    Тренд ADF: ✅ ADF улучшается
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 15:05:22 | Цена BTC: $107305.97
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107305.97
#    SMA: $107286.68
#    Отклонение: $19.29 (0.02%)
#    ADF статистика: -4.4557
#    P-value: 0.0002
#    Стационарность: ✅ ДА
#    Тренд ADF: → ADF стабильна
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107375.51
#    Средняя линия: $107269.77
#    Нижняя полоса: $107164.04
#    Позиция: 🟡 Внутри полос
#    ADF статистика: -1.6903
#    P-value: 0.4361
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: -0.0005%
#    Последняя доходность: 0.0036%
#    Отклонение: 0.0041%
#    Волатильность: 0.0365%
#    ADF статистика: -1.9277
#    P-value: 0.3191
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 15:06:22 | Цена BTC: $107441.99
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107441.99
#    SMA: $107292.64
#    Отклонение: $149.35 (0.14%)
#    ADF статистика: 0.2086
#    P-value: 0.9727
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107429.18
#    Средняя линия: $107285.47
#    Нижняя полоса: $107141.77
#    Позиция: 🔴 Выше верхней полосы
#    ADF статистика: -0.7811
#    P-value: 0.8246
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ⚠️ ADF СНИЖАЕТСЯ
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0081%
#    Последняя доходность: 0.0149%
#    Отклонение: 0.0068%
#    Волатильность: 0.0472%
#    ADF статистика: -1.4389
#    P-value: 0.5635
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ⚠️ ADF СНИЖАЕТСЯ
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 15:07:23 | Цена BTC: $107444.48
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107444.48
#    SMA: $107295.52
#    Отклонение: $148.96 (0.14%)
#    ADF статистика: -1.0905
#    P-value: 0.7189
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107459.78
#    Средняя линия: $107294.20
#    Нижняя полоса: $107128.61
#    Позиция: 🟡 Внутри полос
#    ADF статистика: -1.5954
#    P-value: 0.4859
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0089%
#    Последняя доходность: -0.0256%
#    Отклонение: -0.0345%
#    Волатильность: 0.0487%
#    ADF статистика: -32.2526
#    P-value: 0.0000
#    Стационарность: ✅ ДА
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 15:08:23 | Цена BTC: $107397.96
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107397.96
#    SMA: $107296.12
#    Отклонение: $101.84 (0.09%)
#    ADF статистика: -0.4467
#    P-value: 0.9020
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107458.52
#    Средняя линия: $107295.20
#    Нижняя полоса: $107131.87
#    Позиция: 🟡 Внутри полос
#    ADF статистика: -1.5954
#    P-value: 0.4859
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0077%
#    Последняя доходность: 0.0088%
#    Отклонение: 0.0011%
#    Волатильность: 0.0523%
#    ADF статистика: -3.2788
#    P-value: 0.0159
#    Стационарность: ✅ ДА
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 15:09:23 | Цена BTC: $107430.29
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107430.29
#    SMA: $107300.16
#    Отклонение: $130.13 (0.12%)
#    ADF статистика: -2.5716
#    P-value: 0.0990
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107478.61
#    Средняя линия: $107301.54
#    Нижняя полоса: $107124.47
#    Позиция: 🟡 Внутри полос
#    ADF статистика: -1.5954
#    P-value: 0.4859
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0093%
#    Последняя доходность: 0.0005%
#    Отклонение: -0.0089%
#    Волатильность: 0.0530%
#    ADF статистика: -2.3065
#    P-value: 0.1699
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ⚠️ ADF СНИЖАЕТСЯ
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 15:10:24 | Цена BTC: $107448.75
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107448.75
#    SMA: $107303.95
#    Отклонение: $144.80 (0.13%)
#    ADF статистика: -2.3322
#    P-value: 0.1618
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107499.35
#    Средняя линия: $107309.85
#    Нижняя полоса: $107120.35
#    Позиция: 🟡 Внутри полос
#    ADF статистика: -1.5954
#    P-value: 0.4859
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0098%
#    Последняя доходность: 0.0082%
#    Отклонение: -0.0016%
#    Волатильность: 0.0529%
#    ADF статистика: -4.0740
#    P-value: 0.0011
#    Стационарность: ✅ ДА
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 15:11:24 | Цена BTC: $107508.46
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107508.46
#    SMA: $107309.00
#    Отклонение: $199.46 (0.19%)
#    ADF статистика: -0.3305
#    P-value: 0.9211
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ⚠️ ADF СНИЖАЕТСЯ
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107532.71
#    Средняя линия: $107320.87
#    Нижняя полоса: $107109.02
#    Позиция: 🟡 Внутри полос
#    ADF статистика: -1.9306
#    P-value: 0.3178
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ✅ ADF улучшается
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0201%
#    Последняя доходность: 0.0315%
#    Отклонение: 0.0114%
#    Волатильность: 0.0455%
#    ADF статистика: -4.0755
#    P-value: 0.0011
#    Стационарность: ✅ ДА
#    Тренд ADF: ✅ ADF улучшается
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 15:12:24 | Цена BTC: $107500.21
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107500.21
#    SMA: $107312.79
#    Отклонение: $187.42 (0.17%)
#    ADF статистика: -1.1518
#    P-value: 0.6940
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107553.99
#    Средняя линия: $107329.46
#    Нижняя полоса: $107104.94
#    Позиция: 🟡 Внутри полос
#    ADF статистика: -2.3953
#    P-value: 0.1431
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ✅ ADF улучшается
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0204%
#    Последняя доходность: 0.0000%
#    Отклонение: -0.0204%
#    Волатильность: 0.0449%
#    ADF статистика: -4.1717
#    P-value: 0.0007
#    Стационарность: ✅ ДА
#    Тренд ADF: ✅ ADF улучшается
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 15:13:25 | Цена BTC: $107537.94
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107537.94
#    SMA: $107318.28
#    Отклонение: $219.66 (0.20%)
#    ADF статистика: -1.2917
#    P-value: 0.6330
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ✅ ADF улучшается
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107590.09
#    Средняя линия: $107342.72
#    Нижняя полоса: $107095.35
#    Позиция: 🟡 Внутри полос
#    ADF статистика: -3.5983
#    P-value: 0.0058
#    Стационарность: ✅ ДА
#    Тренд ADF: ✅ ADF улучшается
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0230%
#    Последняя доходность: 0.0000%
#    Отклонение: -0.0230%
#    Волатильность: 0.0447%
# ...
#    Позиция: 🟡 Внутри полос
#    ADF статистика: -30066858347782480.0000
#    P-value: 0.0000
#    Стационарность: ✅ ДА
#    Тренд ADF: → ADF стабильна
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: -0.0067%
#    Последняя доходность: 0.0195%
#    Отклонение: 0.0262%
#    Волатильность: 0.0285%
#    ADF статистика: 0.0318
#    P-value: 0.9611
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ⚠️ ADF СНИЖАЕТСЯ
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 23:05:08 | Цена BTC: $107139.07
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107139.07
#    SMA: $107053.16
#    Отклонение: $85.91 (0.08%)
#    ADF статистика: -2.1549
#    P-value: 0.2230
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107186.23
#    Средняя линия: $107119.02
#    Нижняя полоса: $107051.80
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: -0.0001%
#    Последняя доходность: 0.0155%
#    Отклонение: 0.0156%
#    Волатильность: 0.0308%
#    ADF статистика: -1.0920
#    P-value: 0.7182
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 23:06:08 | Цена BTC: $107131.70
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107131.70
#    SMA: $107056.74
#    Отклонение: $74.96 (0.07%)
#    ADF статистика: 0.3594
#    P-value: 0.9799
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107181.45
#    Средняя линия: $107121.79
#    Нижняя полоса: $107062.12
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0010%
#    Последняя доходность: 0.0153%
#    Отклонение: 0.0143%
#    Волатильность: 0.0303%
#    ADF статистика: -5.5651
#    P-value: 0.0000
#    Стационарность: ✅ ДА
#    Тренд ADF: ✅ ADF улучшается
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 23:07:08 | Цена BTC: $107155.67
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107155.67
#    SMA: $107060.68
#    Отклонение: $94.99 (0.09%)
#    ADF статистика: -2.3514
#    P-value: 0.1559
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107180.02
#    Средняя линия: $107127.70
#    Нижняя полоса: $107075.38
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0005%
#    Последняя доходность: 0.0097%
#    Отклонение: 0.0092%
#    Волатильность: 0.0301%
#    ADF статистика: -2.3629
#    P-value: 0.1525
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 23:08:09 | Цена BTC: $107182.26
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107182.26
#    SMA: $107066.83
#    Отклонение: $115.43 (0.11%)
#    ADF статистика: -0.4409
#    P-value: 0.9030
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107190.52
#    Средняя линия: $107131.89
#    Нижняя полоса: $107073.26
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0011%
#    Последняя доходность: 0.0107%
#    Отклонение: 0.0096%
#    Волатильность: 0.0304%
#    ADF статистика: -0.3239
#    P-value: 0.9220
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ⚠️ ADF СНИЖАЕТСЯ
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 23:09:09 | Цена BTC: $107189.64
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107189.64
#    SMA: $107074.06
#    Отклонение: $115.58 (0.11%)
#    ADF статистика: -8.2167
#    P-value: 0.0000
#    Стационарность: ✅ ДА
#    Тренд ADF: → ADF стабильна
# Ошибка ADF теста для Bollinger Bands: Invalid input, x is constant
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107200.25
#    Средняя линия: $107135.33
#    Нижняя полоса: $107070.42
#    Позиция: 🟡 Внутри полос
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0053%
#    Последняя доходность: 0.0000%
#    Отклонение: -0.0053%
#    Волатильность: 0.0268%
#    ADF статистика: -5.0156
#    P-value: 0.0000
#    Стационарность: ✅ ДА
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 23:10:09 | Цена BTC: $107207.62
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107207.62
#    SMA: $107081.86
#    Отклонение: $125.76 (0.12%)
#    ADF статистика: 1.0262
#    P-value: 0.9945
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107209.63
#    Средняя линия: $107137.40
#    Нижняя полоса: $107065.17
#    Позиция: 🟡 Внутри полос
#    ADF статистика: -3.7417
#    P-value: 0.0036
#    Стационарность: ✅ ДА
#    Тренд ADF: → ADF стабильна
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0059%
#    Последняя доходность: 0.0000%
#    Отклонение: -0.0059%
#    Волатильность: 0.0270%
#    ADF статистика: -5.1935
#    P-value: 0.0000
#    Стационарность: ✅ ДА
#    Тренд ADF: ✅ ADF улучшается
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 23:11:10 | Цена BTC: $107231.94
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107231.94
#    SMA: $107089.96
#    Отклонение: $141.98 (0.13%)
#    ADF статистика: 0.1961
#    P-value: 0.9720
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107230.79
#    Средняя линия: $107143.21
#    Нижняя полоса: $107055.63
#    Позиция: 🔴 Выше верхней полосы
#    ADF статистика: -0.3948
#    P-value: 0.9110
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ⚠️ ADF СНИЖАЕТСЯ
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0051%
#    Последняя доходность: 0.0000%
#    Отклонение: -0.0051%
#    Волатильность: 0.0263%
#    ADF статистика: -0.6728
#    P-value: 0.8537
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 23:12:10 | Цена BTC: $107209.30
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107209.30
#    SMA: $107095.32
#    Отклонение: $113.98 (0.11%)
#    ADF статистика: -1.0105
#    P-value: 0.7494
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ✅ ADF улучшается
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107232.48
#    Средняя линия: $107146.24
#    Нижняя полоса: $107059.99
#    Позиция: 🟡 Внутри полос
#    ADF статистика: -1.5000
#    P-value: 0.5335
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0058%
#    Последняя доходность: 0.0087%
#    Отклонение: 0.0029%
#    Волатильность: 0.0262%
#    ADF статистика: -4.8861
#    P-value: 0.0000
#    Стационарность: ✅ ДА
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 23:13:10 | Цена BTC: $107207.51
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107207.51
#    SMA: $107100.50
#    Отклонение: $107.01 (0.10%)
#    ADF статистика: -0.4391
#    P-value: 0.9034
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107238.84
#    Средняя линия: $107149.04
#    Нижняя полоса: $107059.24
#    Позиция: 🟡 Внутри полос
#    ADF статистика: -2.6874
#    P-value: 0.0762
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ✅ ADF улучшается
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0056%
#    Последняя доходность: 0.0019%
#    Отклонение: -0.0038%
#    Волатильность: 0.0262%
#    ADF статистика: -5.2751
#    P-value: 0.0000
#    Стационарность: ✅ ДА
#    Тренд ADF: ✅ ADF улучшается
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 23:14:11 | Цена BTC: $107207.50
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107207.50
#    SMA: $107105.09
#    Отклонение: $102.41 (0.10%)
#    ADF статистика: -0.7016
#    P-value: 0.8463
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107244.22
#    Средняя линия: $107151.11
#    Нижняя полоса: $107057.99
#    Позиция: 🟡 Внутри полос
#    ADF статистика: -2.6874
#    P-value: 0.0762
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ✅ ADF улучшается
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0075%
#    Последняя доходность: -0.0000%
#    Отклонение: -0.0075%
#    Волатильность: 0.0248%
#    ADF статистика: -4.9716
#    P-value: 0.0000
#    Стационарность: ✅ ДА
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 23:15:11 | Цена BTC: $107225.13
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107225.13
#    SMA: $107108.63
#    Отклонение: $116.50 (0.11%)
#    ADF статистика: -0.6534
#    P-value: 0.8585
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107255.03
#    Средняя линия: $107157.35
#    Нижняя полоса: $107059.67
#    Позиция: 🟡 Внутри полос
#    ADF статистика: -2.6874
#    P-value: 0.0762
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0075%
#    Последняя доходность: 0.0067%
#    Отклонение: -0.0008%
#    Волатильность: 0.0246%
#    ADF статистика: -5.0032
#    P-value: 0.0000
#    Стационарность: ✅ ДА
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 23:16:11 | Цена BTC: $107275.50
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107275.50
#    SMA: $107115.24
#    Отклонение: $160.26 (0.15%)
#    ADF статистика: -3.7423
#    P-value: 0.0036
#    Стационарность: ✅ ДА
#    Тренд ADF: → ADF стабильна
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107286.01
#    Средняя линия: $107168.11
#    Нижняя полоса: $107050.21
#    Позиция: 🟡 Внутри полос
#    ADF статистика: -2.9736
#    P-value: 0.0374
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0106%
#    Последняя доходность: -0.0084%
#    Отклонение: -0.0190%
#    Волатильность: 0.0287%
#    ADF статистика: 0.2397
#    P-value: 0.9744
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 23:17:12 | Цена BTC: $107266.48
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107266.48
#    SMA: $107121.14
#    Отклонение: $145.34 (0.14%)
#    ADF статистика: -5.7653
#    P-value: 0.0000
#    Стационарность: ✅ ДА
#    Тренд ADF: ✅ ADF улучшается
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107298.83
#    Средняя линия: $107173.64
#    Нижняя полоса: $107048.45
#    Позиция: 🟡 Внутри полос
#    ADF статистика: -4.1091
#    P-value: 0.0009
#    Стационарность: ✅ ДА
#    Тренд ADF: ✅ ADF улучшается
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0136%
#    Последняя доходность: -0.0082%
#    Отклонение: -0.0218%
#    Волатильность: 0.0240%
#    ADF статистика: -0.6217
#    P-value: 0.8660
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 23:18:12 | Цена BTC: $107269.32
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107269.32
#    SMA: $107126.32
#    Отклонение: $143.00 (0.13%)
#    ADF статистика: -3.7396
#    P-value: 0.0036
#    Стационарность: ✅ ДА
#    Тренд ADF: → ADF стабильна
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107311.00
#    Средняя линия: $107181.10
#    Нижняя полоса: $107051.20
#    Позиция: 🟡 Внутри полос
#    ADF статистика: -2.9736
#    P-value: 0.0374
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0098%
#    Последняя доходность: 0.0000%
#    Отклонение: -0.0098%
#    Волатильность: 0.0209%
#    ADF статистика: -4.1594
#    P-value: 0.0008
#    Стационарность: ✅ ДА
#    Тренд ADF: ✅ ADF улучшается
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 23:19:12 | Цена BTC: $107271.41
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107271.41
#    SMA: $107131.27
#    Отклонение: $140.14 (0.13%)
#    ADF статистика: -1.4434
#    P-value: 0.5613
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ⚠️ ADF СНИЖАЕТСЯ
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107319.40
#    Средняя линия: $107187.98
#    Нижняя полоса: $107056.55
#    Позиция: 🟡 Внутри полос
#    ADF статистика: -0.3333
#    P-value: 0.9206
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ⚠️ ADF СНИЖАЕТСЯ
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0104%
#    Последняя доходность: 0.0122%
#    Отклонение: 0.0018%
#    Волатильность: 0.0210%
#    ADF статистика: -3.0054
#    P-value: 0.0344
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
#
# ================================================================================
# Время: 23:20:13 | Цена BTC: $107287.27
# ================================================================================
#
# 📊 СТРАТЕГИЯ 1: Отклонение от SMA(50)
#    Текущая цена: $107287.27
#    SMA: $107136.97
#    Отклонение: $150.30 (0.14%)
#    ADF статистика: -1.3567
#    P-value: 0.6028
#    Стационарность: ❌ НЕТ
#    Тренд ADF: ⚠️ ADF СНИЖАЕТСЯ
#
# 📊 СТРАТЕГИЯ 2: Bollinger Bands(20, 2)
#    Верхняя полоса: $107331.00
#    Средняя линия: $107198.31
#    Нижняя полоса: $107065.61
#    Позиция: 🟡 Внутри полос
#    ADF статистика: -64733648253724.5547
#    P-value: 0.0000
#    Стационарность: ✅ ДА
#    Тренд ADF: → ADF стабильна
#
# 📊 СТРАТЕГИЯ 3: Отклонение доходности от средней
#    Средняя доходность: 0.0095%
#    Последняя доходность: 0.0015%
#    Отклонение: -0.0080%
#    Волатильность: 0.0210%
#    ADF статистика: -3.1740
#    P-value: 0.0215
#    Стационарность: ❌ НЕТ
#    Тренд ADF: → ADF стабильна
#
# ⏳ Следующее обновление через 60 секунд...
